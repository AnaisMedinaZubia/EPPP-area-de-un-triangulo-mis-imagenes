# %% [markdown]
# ### Anais Medina NL Fecha 25/Mar/2026 ❣
# ---
# # Calcular Area de un triangulo
# ![Logo de Markdown](https://raw.githubusercontent.com/AnaisMedinaZubia/EPPP-area-de-un-triangulo-mis-imagenes/refs/heads/main/Df%20area_triangulo.JPG)
# ---
#
# ---
# ## Formula para calcular area
# $A=\frac{b.h}{2}$
#
# ---
#
# ## Datos de entrada
# $A$ ?
#
#
# ---
# ## Diagrama de flujo en lucidchart
# ![Logo de Markdown](https://raw.githubusercontent.com/AnaisMedinaZubia/EPPP-area-de-un-triangulo-mis-imagenes/refs/heads/main/DF%20Area_triangulo.png)

# %%
# Calcular area de un triangulo
# Variables B, H, A
# Formulas A = B * H / 2
import math
print("Calcular area de un triangulo")
B = float(input("Ingrese el valor de la B: "))
H = float(input("Ingrese el valor de la H: "))
area = B * H / 2
print("El area del triangulo es: ", area)
print("Anais Medina NL = 36")
# Out:
# Calcular area de un triangulo
# Ingrese el valor de la B: 17
# Ingrese el valor de la H: 6
# El area del triangulo es:  51.0
# Anais Medina NL = 36

# %% [markdown]
# # Relacion entre codigo y DF en tldraw
# ![Logo de Markdown](https://raw.githubusercontent.com/AnaisMedinaZubia/EPPP-area-de-un-triangulo-mis-imagenes/refs/heads/main/DG%20Area_triangulo.JPG)
